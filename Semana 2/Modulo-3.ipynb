# %% [markdown]
# # Módulo 3 MOOC Python para Ciencia de Datos

# %% [markdown]
# ### Clase 1: ¿Por qué es importante una visualización adecuada de los datos y resultados?

# %% [markdown]
# Lo primero, antes de decir la importancia de la Visualización de Datos, es saber qué es. Luego, según la página web de Tableau, uno de los softwares de visualización analítica más utilizados, *la visualización de datos es la representación gráfica de información y datos mediante el uso de elementos visuales como cuadros, gráficos y mapas. Las herramientas de visualización de datos proporcionan una forma accesible de ver y comprender tendencias, valores atípicos y patrones en los datos.*
#
# Sabiendo que es la visualización de datos, se tiene que la `importancia fundamental` que tiene es la de hacer de la información con que se cuenta más comprensible, de manera que se pueda entender de manera rápida e intuitiva, ver tendencias, valores atípicos, ciclos, entre otros factores relevantes. Debido a esto, es importante que se tengan buenas visualizaciones.
#
# **¿Qué es una buena visualización?**
#
# Es difícil de describir lo que es una buena visualización de los datos, sin embargo, lo más importante es que esta sea efectiva al describir la información, es un balance entre la forma y la funcionalidad. Debido a esto, lo primero que es importante definir es que tipo de gráfico debemos usar basados en lo que queremos mostrar de los datos. Lo más probable es que los primeros gráficos que se les ocurran sean de barras o uno circular, sin embargo, hay un gran abanico de tipos de visualizaciones, dentro de las que podemos encontrar:
# -	Gráficos de área
# -	Gráficos de barra
# -	Gráficos de cajas y bigotes (boxplot)
# -	Diagramas de dispersión
# -	Histogramas
#
# Estos son solo ejemplos y existen muchos tipos más, por lo que es importante definir que vamos a mostrar antes de elegir un tipo. Por ejemplo, si ustedes quisieran mostrar la dispersión de unos datos que se están analizando, no se puede utilizar el mismo tipo de gráfico que se utilizaría para mostrar la tendencia de ciertos datos. También, se debe tener en cuenta que tipo de dato se debe graficar (categórica o continua).

# %% [markdown]
# ### Clase 2: ¿Cómo crear gráficos en Python?

# %% [markdown]
# Como se mencionó anteriormente, las principales librerías de Python para visualizar la información contenida dentro de las Bases de Datos son `Matplotlib` y `Seaborn`. Luego, para realizar algunos ejemplos lo primero que se hace es importar los módulos necesarios.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.transforms as transforms
import seaborn as sns

# %% [markdown]
# Con los módulos importados, se procede a importar la información contenida en el archivo *Datos.xls*

# %%
GRD_sheet = pd.read_excel("https://docs.google.com/spreadsheets/d/1hN0CvoHmepBHkrEd0TCxbVmhhAO8dYHw/edit?usp=share_link&ouid=118038290203431260023&rtpof=true&sd=true", sheet_name = "GRD", header = 0, index_col = None)
Hosp_sheet = pd.read_excel("C:/Users/Tomás Barrientos/Downloads/_Datos.xls", sheet_name = "Hospitales", header = 0, index_col = None)
Info_sheet = pd.read_excel("C:/Users/Tomás Barrientos/Downloads/_Datos.xls", sheet_name = "Información Histórica", header = 0, index_col = None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 GRD_sheet = pd.read_excel("https://docs.google.com/spreadsheets/d/1hN0CvoHmepBHkrEd0TCxbVmhhAO8dYHw/edit?usp=share_link&ouid=118038290203431260023&rtpof=true&sd=true", sheet_name = "GRD", header = 0, index_col = None)
#       2 Hosp_sheet = pd.read_excel("C:/Users/Tomás Barrientos/Downloads/_Datos.xls", sheet_name = "Hospitales", header = 0, index_col = None)
#       3 Info_sheet = pd.read_excel("C:/Users/Tomás Barrientos/Downloads/_Datos.xls", sheet_name = "Información Histórica", header = 0, index_col = None)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1563     ext = inspect_excel_format(
#    1564         content_or_path=path_or_buffer, storage_options=storage_options
#    1565     )
#    1566     if ext is None:
# -> 1567         raise ValueError(
#    1568             "Excel file format cannot be determined, you must specify "
#    1569             "an engine manually."
#    1570         )
#    1572 engine = config.get_option(f"io.excel.{ext}.reader", silent=True)
#    1573 if engine == "auto":
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %%
GRD_sheet.head(3)
# Out:
#   ID GRD    Nombre GRD  Costo resolución en Clínica Privada [MM$]
# 0   GRD1     Coronario                                      7.917
# 1   GRD2      Hepático                                      3.417
# 2   GRD3  Respiratorio                                      2.915

# %%
Hosp_sheet.head(3)
# Out:
#                             Nombre Servicio de Salud  \
# 0  Metropolitano Norte                           ...
# 1  Metropolitano Occidente                       ...
# 2  Metropolitano Occidente                       ...
#
#                    Nombre Establecimiento  Área Cuidados Intensivos Adultos  \
# 0          Complejo Hospitalario San José                                11
# 1  Hospital Adalberto Steeger (Talagante)                                 6
# 2         Hospital Dr. Félix Bulnes Cerda                                 3
#
#    Área Cuidados Intermedios Adulto  Total Camas Críticas  \
# 0                                33                    44
# 1                                11                    17
# 2                                 6                     9
#
#    Máxima cantidad de camas a aumetar  Costo de instalar una cama [MM$]  \
# 0                                  10                              1407
# 1                                   5                              1263
# 2                                   5                              1310
#
#    Costo de operación anual de una cama [MM$]  Costo diario GRD1 [MM$]  \
# 0                                        47.2                    0.593
# 1                                        62.1                    0.493
# 2                                        65.9                    0.580
#
#    Costo diario GRD2 [MM$]  Costo diario GRD3 [MM$]  Costo diario GRD4 [MM$]  \
# 0                    0.509                    0.367                    0.492
# 1                    0.357                    0.429                    0.382
# 2                    0.325                    0.375                    0.409
#
#    Costo diario GRD5 [MM$]  Costo diario GRD6 [MM$]  Costo diario GRD7 [MM$]  \
# 0                    0.524                    0.405                    0.571
# 1                    0.469                    0.386                    0.543
# 2                    0.561                    0.362                    0.328
#
#    Costo diario GRD8 [MM$]  Costo diario GRD9 [MM$]  Costo diario GRD10 [MM$]
# 0                    0.474                    0.498                     0.305
# 1                    0.362                    0.564                     0.333
# 2                    0.314                    0.536                     0.436

# %%
Info_sheet.head(3)
# Out:
#    Número de llegada                        Nombre Establecimiento   GRD  \
# 0                  1  Instituto Traumatológico Dr. Teodoro Gebauer  GRD3
# 1                  2           Hospital Clínico San Borja-Arriarán  GRD7
# 2                  3                    Hospital Dr. Luis Tisné B.  GRD7
#
#    Día de llegada  Día de salida  Estadia
# 0               1              4        3
# 1               1              5        4
# 2               1              5        4

# %% [markdown]
# Con las distintas hojas del archivo importadas, se procede a explicar de manera breve cada librería y realizar distintos ejemplos de lo que se puede visualizar utilizando `Matplotlib` y `Seaborn`.

# %% [markdown]
# **Matplotlib**
#
# Matplotlib es una biblioteca completa para realizar distintas visualizaciones en Python. Lo interesante de esta librería es que viene incluida dentro de Pandas, es decir, existe un método en Pandas para graficar que utiliza por defecto el motor de visualización entregado por Matplotlib lo que hace más fácil e intuitivo su uso. A continuación, se muestra como realizar distintos gráficos con `Matplotlib`

# %%
GRD_INFO = Info_sheet[['Número de llegada', 'GRD']].groupby('GRD').count()
GRD_INFO.rename({'GRD': 'ID GRD', 'Número de llegada': 'Conteo'}, axis=1, inplace=True)
GRD_INFO
# Out:
#        Conteo
# GRD
# GRD1     6587
# GRD10    6479
# GRD2     6469
# GRD3     6597
# GRD4     6422
# GRD5     6684
# GRD6     6502
# GRD7     6645
# GRD8     6497
# GRD9     6652

# %%
ax = GRD_INFO.plot.bar(figsize=(6,5))
ax.bar_label(ax.containers[0])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
ax = GRD_INFO.plot.barh(figsize=(8,5))
ax.bar_label(ax.containers[0])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
ax = GRD_INFO.plot.pie(y = "Conteo", autopct=lambda p: '{:.0f}'.format(p*GRD_INFO["Conteo"].sum()/100), figsize=(6,5))
ax.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))
plt.show()

# %%
ax = GRD_INFO.plot(kind = 'bar', figsize=(6,5))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.axhline(y=GRD_INFO['Conteo'].max(), color='r', linestyle='-',linewidth=3.0)
trans = transforms.blended_transform_factory(
    ax.get_yticklabels()[0].get_transform(), ax.transData)
ax.text(0,GRD_INFO['Conteo'].max(), "{:.0f}".format(GRD_INFO['Conteo'].max()), color="red", transform=trans, 
        ha="right", va="center")
plt.grid(color='c', linestyle='-', linewidth=0.5)
plt.show()

# %% [markdown]
# **Seaborn**
#
# Seaborn es una biblioteca de visualización de datos de Python basada en Matplotlib. Proporciona una interfaz de alto nivel para dibujar gráficos estadísticos atractivos e informativos. A diferencia de Matplotlib, esta no viene por defecto en Pandas. A continuación, se muestra como realizar distintos gráficos con `Seaborn`

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.countplot(y="GRD", data=Info_sheet, color="c")
plt.show()

# %%
sns.catplot(x="GRD", kind="count", data=Info_sheet, height=4, aspect=2)
plt.show()

# %% [markdown]
# **Pregunta 1**

# %%
Hosp_sheet.groupby("Nombre Servicio de Salud").mean().plot(kind="bar", y="Costo diario GRD1 [MM$]")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:2377, in GroupBy.mean.<locals>.<lambda>(x)
#    2374 else:
#    2375     result = self._cython_agg_general(
#    2376         "mean",
# -> 2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11980     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string 'Hospital Clínico San Borja-ArriaránHospital de Urgencia Asistencia Pública Dr. Alejandro del RíoHospital el Carmen' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Hosp_sheet.groupby("Nombre Servicio de Salud").mean().plot(kind="bar", y="Costo diario GRD1 [MM$]")
#       2 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:2375, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2368     return self._numba_agg_general(
#    2369         grouped_mean,
#    2370         executor.float_dtype_mapping,
#    2371         engine_kwargs,
#    2372         min_periods=0,
#    2373     )
#    2374 else:
# -> 2375     result = self._cython_agg_general(
#    2376         "mean",
#    2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1926, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1923     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924     return result
# -> 1926 new_mgr = data.grouped_reduce(array_func)
#    1927 res = self._wrap_agged_manager(new_mgr)
#    1928 out = self._wrap_aggregated_output(res)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1923, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1920 else:
#    1921     return result
# -> 1923 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1875, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1874     # preserve the kind of exception that raised
# -> 1875     raise type(err)(msg) from err
#    1877 if ser.dtype == object:
#    1878     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# **Pregunta 2**

# %%
sns.histplot(data = Info_sheet[["Día de llegada","Número de llegada"]].groupby('Día de llegada').count())
plt.show()

# %% [markdown]
# ### Clase 3: ¿Cómo crear una interfaz adecuada?

# %% [markdown]
# Al utilizar **Seaborn** y **Matplotlib** se pueden realizar gráficos y figuras que nos permitan entender de mejor manera los datos, tendencias y patrones. Sin embargo, al utilizar estas y los comandos de Pandas para realizar visualizaciones se generan gráficos estáticos, sobre los cuales no se puede interactuar. Pero ¿No sería mejor poder interactuar con los gráficos, haciendo zoom o teniendo un poco mas de información de lo que estamos viendo?
#
# Al utilizar gráficos interactivos, nosotros como usuarios podemos modificar elementos de los estos sin la necesidad de cambiar el código o volver a correr distintas instancias. Por ejemplo, si usted estuviera viendo un gráfico del sistema de salud en donde solo quisiera conocer la información de un solo GRD o solamente un hospital, estos gráficos interactivos lo permiten sin necesidad de volver a correr el código. Así, con estos gráficos se puede entender aún mejor la información.
#
# Para esto existen los `Dashboards`, los cuales son herramientas que nos permiten realizar una interfaz visual a manera de reporte, que nos permiten entender de manera rápida la información. Nos dan una imagen de lo que cuentan los datos. De manera simple, estos son un conjunto de diferentes gráficos que se presentan de manera ordenada en una forma de grilla que nos permiten obtener distintos insights en un mismo lugar. Luego, vamos a realizar un *Dashboard* a continuación. Para esto se importan los módulos necesarios.

# %%
##Antes de importar pandas_bokeh se debe importar numpy o pandas, De lo contrario se generaría un error
import pandas as pd
import numpy as np
import pandas_bokeh
# Out:
# BokehDeprecationWarning: 'tile_providers module' was deprecated in Bokeh 3.0.0 and will be removed, use 'add_tile directly' instead.

# %% [markdown]
# Luego, con el comando a continuación se pide a Bokeh que el `Dashboard` se visualice en Pandas

# %%
pandas_bokeh.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c061b0f6-5f6f-44f7-b17a-5fde4c40a974">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Luego, definimos los distintos gráficos a mostrar.

# %%
p_scatter= Hosp_sheet.groupby(['Nombre Servicio de Salud']).mean().plot_bokeh(kind="scatter",y="Costo de instalar una cama [MM$]",color='blue',plot_data_points=True,show_figure=False)
p_bar= GRD_sheet.plot_bokeh(kind="barh", y = "Costo resolución en Clínica Privada [MM$]",color='#d01c8b',plot_data_points=True,show_figure=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:2377, in GroupBy.mean.<locals>.<lambda>(x)
#    2374 else:
#    2375     result = self._cython_agg_general(
#    2376         "mean",
# -> 2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11980     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string 'Hospital Clínico San Borja-ArriaránHospital de Urgencia Asistencia Pública Dr. Alejandro del RíoHospital el Carmen' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 p_scatter= Hosp_sheet.groupby(['Nombre Servicio de Salud']).mean().plot_bokeh(kind="scatter",y="Costo de instalar una cama [MM$]",color='blue',plot_data_points=True,show_figure=False)
#       2 p_bar= GRD_sheet.plot_bokeh(kind="barh", y = "Costo resolución en Clínica Privada [MM$]",color='#d01c8b',plot_data_points=True,show_figure=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:2375, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2368     return self._numba_agg_general(
#    2369         grouped_mean,
#    2370         executor.float_dtype_mapping,
#    2371         engine_kwargs,
#    2372         min_periods=0,
#    2373     )
#    2374 else:
# -> 2375     result = self._cython_agg_general(
#    2376         "mean",
#    2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1926, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1923     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924     return result
# -> 1926 new_mgr = data.grouped_reduce(array_func)
#    1927 res = self._wrap_agged_manager(new_mgr)
#    1928 out = self._wrap_aggregated_output(res)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1923, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1920 else:
#    1921     return result
# -> 1923 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1875, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1874     # preserve the kind of exception that raised
# -> 1875     raise type(err)(msg) from err
#    1877 if ser.dtype == object:
#    1878     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
p_line = Info_sheet[['GRD','Estadia']].groupby('GRD').mean().plot_bokeh(kind="line",show_figure=False)
p_pie= GRD_INFO.plot_bokeh.pie(y='Conteo',show_figure=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 p_line = Info_sheet[['GRD','Estadia']].groupby('GRD').mean().plot_bokeh(kind="line",show_figure=False)
#       2 p_pie= GRD_INFO.plot_bokeh.pie(y='Conteo',show_figure=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas_bokeh\plot.py:1785, in FramePlotMethods.__call__(self, *args, **kwargs)
#    1784 def __call__(self, *args, **kwargs):
# -> 1785     return plot(self.df, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas_bokeh\plot.py:439, in plot(df_in, x, y, kind, figsize, use_index, title, legend, logx, logy, xlabel, ylabel, xticks, yticks, xlim, ylim, fontsize_title, fontsize_label, fontsize_ticks, fontsize_legend, color, colormap, category, histogram_type, stacked, weights, bins, normed, cumulative, show_average, plot_data_points, plot_data_points_size, number_format, disable_scientific_axes, show_figure, return_html, panning, zooming, sizing_mode, toolbar_location, hovertool, hovertool_string, rangetool, vertical_xlabel, x_axis_location, webgl, reuse_plot, **kwargs)
#     432     xlabelname = (
#     433         figure_options["x_axis_label"]
#     434         if figure_options.get("x_axis_label", "") != ""
#     435         else "x"
#     436     )
#     438 # Create Figure for plotting:
# --> 439 p = figure(**figure_options)
#     440 if "x_axis_type" not in figure_options:
#     441     figure_options["x_axis_type"] = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\bokeh\plotting\_figure.py:192, in figure.__init__(self, *arg, **kw)
#     190 for name in kw.keys():
#     191     if name not in names:
# --> 192         self._raise_attribute_error_with_matches(name, names | opts.properties())
#     194 super().__init__(*arg, **kw)
#     196 self.x_range = get_range(opts.x_range)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\bokeh\core\has_props.py:375, in HasProps._raise_attribute_error_with_matches(self, name, properties)
#     372 if not matches:
#     373     matches, text = sorted(properties), "possible"
# --> 375 raise AttributeError(f"unexpected attribute {name!r} to {self.__class__.__name__}, {text} attributes are {nice_join(matches)}")
#
# AttributeError: unexpected attribute 'plot_width' to figure, similar attributes are outer_width, width or min_width

# %% [markdown]
# Por último, se realiza el *Dashboard*

# %%
#Make Dashboard with Grid Layout: 
pandas_bokeh.plot_grid([[p_bar, p_scatter],[p_line, p_pie]], plot_width=450)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 #Make Dashboard with Grid Layout:
# ----> 2 pandas_bokeh.plot_grid([[p_bar, p_scatter],[p_line, p_pie]], plot_width=450)
#
# NameError: name 'p_bar' is not defined

# %% [markdown]
# **Pregunta 1**

# %%
Info_sheet.groupby("Día de llegada").count().plot(y = "Número de llegada")
plt.show()

# %% [markdown]
# **Pregunta 2**

# %%
p_hist = Info_sheet.groupby('Día de llegada').count().plot_bokeh(kind="hist", y = "Número de llegada",show_figure=False)
pandas_bokeh.plot_grid([[p_bar, p_scatter],[p_line, p_pie], [p_hist]], plot_width=450)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 p_hist = Info_sheet.groupby('Día de llegada').count().plot_bokeh(kind="hist", y = "Número de llegada",show_figure=False)
#       2 pandas_bokeh.plot_grid([[p_bar, p_scatter],[p_line, p_pie], [p_hist]], plot_width=450)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas_bokeh\plot.py:1785, in FramePlotMethods.__call__(self, *args, **kwargs)
#    1784 def __call__(self, *args, **kwargs):
# -> 1785     return plot(self.df, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas_bokeh\plot.py:439, in plot(df_in, x, y, kind, figsize, use_index, title, legend, logx, logy, xlabel, ylabel, xticks, yticks, xlim, ylim, fontsize_title, fontsize_label, fontsize_ticks, fontsize_legend, color, colormap, category, histogram_type, stacked, weights, bins, normed, cumulative, show_average, plot_data_points, plot_data_points_size, number_format, disable_scientific_axes, show_figure, return_html, panning, zooming, sizing_mode, toolbar_location, hovertool, hovertool_string, rangetool, vertical_xlabel, x_axis_location, webgl, reuse_plot, **kwargs)
#     432     xlabelname = (
#     433         figure_options["x_axis_label"]
#     434         if figure_options.get("x_axis_label", "") != ""
#     435         else "x"
#     436     )
#     438 # Create Figure for plotting:
# --> 439 p = figure(**figure_options)
#     440 if "x_axis_type" not in figure_options:
#     441     figure_options["x_axis_type"] = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\bokeh\plotting\_figure.py:192, in figure.__init__(self, *arg, **kw)
#     190 for name in kw.keys():
#     191     if name not in names:
# --> 192         self._raise_attribute_error_with_matches(name, names | opts.properties())
#     194 super().__init__(*arg, **kw)
#     196 self.x_range = get_range(opts.x_range)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\bokeh\core\has_props.py:375, in HasProps._raise_attribute_error_with_matches(self, name, properties)
#     372 if not matches:
#     373     matches, text = sorted(properties), "possible"
# --> 375 raise AttributeError(f"unexpected attribute {name!r} to {self.__class__.__name__}, {text} attributes are {nice_join(matches)}")
#
# AttributeError: unexpected attribute 'plot_width' to figure, similar attributes are outer_width, width or min_width

# %%
#EVALUACIÓN 3 PREGUNTA 1
